# %% [markdown]
# # Task 8

# %% [markdown]
# # Customer Travel Analysis

# %%
# Importing necessary libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import cufflinks as cf
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# suppressing warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading Dataset

# %%
df=pd.read_csv('Customertravel.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         954 non-null    int64
#  1   FrequentFlyer               954 non-null    object
#  2   AnnualIncomeClass           954 non-null    object
#  3   ServicesOpted               954 non-null    int64
#  4   AccountSyncedToSocialMedia  954 non-null    object
#  5   BookedHotelOrNot            954 non-null    object
#  6   Target                      954 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 52.3+ KB

# %%
df.isna().sum()
# Out:
# Age                           0
# FrequentFlyer                 0
# AnnualIncomeClass             0
# ServicesOpted                 0
# AccountSyncedToSocialMedia    0
# BookedHotelOrNot              0
# Target                        0
# dtype: int64

# %%
df.head()
# Out:
#    Age FrequentFlyer AnnualIncomeClass  ServicesOpted  \
# 0   34            No     Middle Income              6
# 1   34           Yes        Low Income              5
# 2   37            No     Middle Income              3
# 3   30            No     Middle Income              2
# 4   30            No        Low Income              1
#
#   AccountSyncedToSocialMedia BookedHotelOrNot  Target
# 0                         No              Yes       0
# 1                        Yes               No       1
# 2                        Yes               No       0
# 3                         No               No       0
# 4                         No               No       0

# %%
df['AccountSyncedToSocialMedia'].value_counts()
# Out:
# AccountSyncedToSocialMedia
# No     594
# Yes    360
# Name: count, dtype: int64

# %%
sns.countplot(x='AccountSyncedToSocialMedia',data=df)
# Out:
# <Axes: xlabel='AccountSyncedToSocialMedia', ylabel='count'>

# %%
df['Age'].value_counts()
# Out:
# Age
# 30    236
# 37    126
# 34    107
# 31    103
# 28     71
# 29     70
# 36     67
# 27     62
# 35     52
# 38     31
# 33     29
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Age'])
plt.title("Most traveller's age")
# Out:
# Text(0.5, 1.0, "Most traveller's age")

# %%
sns.distplot(df['Age'],kde=True)
plt.title("Most traveller's age")
# Out:
# Text(0.5, 1.0, "Most traveller's age")

# %%
sns.countplot(x='ServicesOpted',data=df)
# Out:
# <Axes: xlabel='ServicesOpted', ylabel='count'>

# %%
sns.countplot(x='ServicesOpted',data=df,hue='AnnualIncomeClass')
plt.legend(bbox_to_anchor=(1.5,1),title='Annual income Class')

# %%
df['FrequentFlyer'].value_counts()
# Out:
# FrequentFlyer
# No           608
# Yes          286
# No Record     60
# Name: count, dtype: int64

# %%
sns.countplot(x='FrequentFlyer',data=df)
# Out:
# <Axes: xlabel='FrequentFlyer', ylabel='count'>

# %%
sns.countplot(x='AnnualIncomeClass',data=df)
# Out:
# <Axes: xlabel='AnnualIncomeClass', ylabel='count'>

# %%
df['BookedHotelOrNot'].value_counts()
# Out:
# BookedHotelOrNot
# No     576
# Yes    378
# Name: count, dtype: int64

# %%
BookedHotel=df['BookedHotelOrNot'].value_counts()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(6,6))
plt.pie(x=BookedHotel)
plt.legend(df['BookedHotelOrNot'])
plt.title('Booked Hotel')
# Out:
# Text(0.5, 1.0, 'Booked Hotel')

# %%
df['Target'].value_counts()
# Out:
# Target
# 0    730
# 1    224
# Name: count, dtype: int64

# %%
Target=df['Target'].value_counts()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(6,6))
plt.pie(x=Target)
plt.legend(df['BookedHotelOrNot'],title='BookedHotelOrNot')
plt.title('Booked Hotel')
# Out:
# Text(0.5, 1.0, 'Booked Hotel')

# %%
pip install chart_studio

# %%
df.iplot(kind='pie',x=BookedHotel)
# Out:
# ---------------------------------------------------------------------------
# CufflinksError                            Traceback (most recent call last)
# Cell In[232], line 1
# ----> 1 df.iplot(kind='pie',x=BookedHotel)
#
# File ~\anaconda3\Lib\site-packages\cufflinks\plotlytools.py:1005, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1003 elif kind=='pie':
#    1004 	if not labels:
# -> 1005 		raise CufflinksError('Missing: labels')
# ...
